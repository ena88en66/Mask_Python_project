# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(60000,28,28,1)/255
x_test = x_test.reshape(10000,28,28,1)/255

# %%
x_train[28].shape
# Out:
# (28, 28, 1)

# %%
y_train[87]
# Out:
# 9

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train = to_categorical(y_train,10)

# %%
y_test = to_categorical(y_test,10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D , MaxPooling2D
from tensorflow.keras.layers import Dense , Flatten
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential()

# %%
model.add(Conv2D(16,(3,3),padding='same',input_shape=(28,28,1),activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Conv2D(32,(3,3),padding='same',activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Conv2D(64,(3,3),padding='same',activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
#7*7變一半會怎麼樣

# %%
model.add(Flatten())

# %%
model.add(Dense(54, activation='relu'))

# %%
model.add(Dense(10,activation='softmax'))

# %%
###看一下我們的神經網路

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 54)                31158
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                550
# =================================================================
# Total params: 55,004
# Trainable params: 55,004
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse',optimizer=SGD(lr=0.087),metrics=["accuracy"])

# %%
model.fit(x_train, y_train, batch_size=128, epochs=12)
# Out:
# Train on 60000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 20s 332us/sample - loss: 0.0892 - accuracy: 0.2173
# Epoch 2/12
# 60000/60000 [==============================] - 23s 381us/sample - loss: 0.0838 - accuracy: 0.4726
# Epoch 3/12
# 60000/60000 [==============================] - 23s 379us/sample - loss: 0.0395 - accuracy: 0.7638
# Epoch 4/12
# 60000/60000 [==============================] - 23s 378us/sample - loss: 0.0164 - accuracy: 0.8983
# Epoch 5/12
# 60000/60000 [==============================] - 23s 384us/sample - loss: 0.0120 - accuracy: 0.9240
# Epoch 6/12
# 60000/60000 [==============================] - 23s 386us/sample - loss: 0.0097 - accuracy: 0.9388
# Epoch 7/12
# 60000/60000 [==============================] - 31s 510us/sample - loss: 0.0084 - accuracy: 0.9469
# Epoch 8/12
# 60000/60000 [==============================] - 32s 535us/sample - loss: 0.0075 - accuracy: 0.9522
# Epoch 9/12
# 60000/60000 [==============================] - 32s 540us/sample - loss: 0.0068 - accuracy: 0.9571
# Epoch 10/12
# 60000/60000 [==============================] - 32s 534us/sample - loss: 0.0063 - accuracy: 0.9598
# Epoch 11/12
# 60000/60000 [==============================] - 34s 570us/sample - loss: 0.0059 - accuracy: 0.9627
# Epoch 12/12
# 60000/60000 [==============================] - 34s 563us/sample - loss: 0.0055 - accuracy: 0.9647

# %%
result = model.predict_classes(x_test)

# %%
def my_predict(n):
    print('我的CNN預測是',result[n])
    X = x_test[n].reshape(28,28)
    plt.imshow(X, cmap='Greys')

# %%
from ipywidgets import interact_manual

# %%
interact_manual(my_predict, n=(0,9999))
# Out:
# interactive(children=(IntSlider(value=4999, description='n', max=9999), Button(description='Run Interact', sty…
# <function __main__.my_predict(n)>

# %%
score = model.evaluate(x_test,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
loss , accuracy = score

# %%
print("測試資料的正確率為", accuracy)
# Out:
# 測試資料的正確率為 0.968
