# %% [markdown]
# ### 1.載入套件

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import some useful packages
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact, IntSlider, FloatSlider

import tensorflow as tf
import tensorflow.keras.backend as K

# Layers for FNN
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Lambda, concatenate
from tensorflow.keras.layers import Dense

# Optimizers for training
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import metrics

# Losses for training
from tensorflow.keras import losses

# For data preprocessing
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### 2.載入資料並進行處理

# %%
# Load dataset
(X_train, y_train0), (X_test, y_test0) = datasets.mnist.load_data()

# Reshape size
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)

# Normalize the range of featurs
X_train = X_train / X_train.max()
X_test = X_test / X_test.max()

# One-hot encoding
y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)

# %% [markdown]
# ### 3.架構VAE模型

# %% [markdown]
# * 模型簡介
#     - Encoder層的dense分別為784、200、50
#     - Decoder層的dense分別為50、200、784
#     - activation都用sigmoid
#     - optimizer用Adam(7e-3)
#     - batch_size=256、epochs=20

# %%
# 定義function
enc_1 = Dense(200, activation='sigmoid')
enc_2 = Dense(50, activation='sigmoid')

enc_mean = Dense(2)
enc_log_var = Dense(2)

dec_3 = Dense(50, activation='sigmoid')
dec_2 = Dense(200, activation='sigmoid')
dec_1 = Dense(784, activation='sigmoid')

# %%
# Define Encoder part of VAE
x = Input(shape=(784,))
enc_x = enc_2(enc_1(x))
enc_x = enc_2(enc_1(x))

z_mean = enc_mean(enc_x)
z_log_var = enc_log_var(enc_x)

# %%
# 抽樣函數
def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean = 0 and std = 1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %%
# Sampling function wrapped as a Keras layer
z = Lambda(sampling, output_shape=(2,))([z_mean, z_log_var])

# %%
# Define Decoder part of VAE
z_input = Input(shape=(2,))
x_hat = dec_1(dec_2(dec_3(z_input)))

# %%
x_hat = dec_1(dec_2(dec_3(z)))
VAE = Model(x, x_hat)
VAE.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 200)          157000      input_6[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 50)           10050       dense_19[1][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 2)            102         dense_20[1][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 2)            102         dense_20[1][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 2)            0           dense_21[0][0]
#                                                                  dense_22[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 50)           150         lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 200)          10200       dense_23[1][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 784)          157584      dense_24[1][0]
# ==================================================================================================
# Total params: 335,188
# Trainable params: 335,188
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Loss Function
reconstruction_loss = 784 * losses.mean_squared_error(x, x_hat)

kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5

vae_loss = K.mean(reconstruction_loss + kl_loss)

VAE.add_loss(vae_loss)

# %%
VAE.compile(optimizer=Adam(7e-3)) #編譯模型
# Out:
# WARNING:tensorflow:Output dense_25 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to dense_25.

# %%
VAE.fit(X_train, batch_size=256, epochs=20) #訓練模型
# Out:
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 52.8056
# Epoch 2/20
# 60000/60000 [==============================] - 3s 52us/sample - loss: 47.3445
# Epoch 3/20
# 60000/60000 [==============================] - 3s 50us/sample - loss: 43.9503
# Epoch 4/20
# 60000/60000 [==============================] - 3s 50us/sample - loss: 41.6655
# Epoch 5/20
# 60000/60000 [==============================] - 3s 50us/sample - loss: 40.3341
# Epoch 6/20
# 60000/60000 [==============================] - 3s 51us/sample - loss: 39.3646
# Epoch 7/20
# 60000/60000 [==============================] - 3s 51us/sample - loss: 38.5182
# Epoch 8/20
# 60000/60000 [==============================] - 3s 51us/sample - loss: 37.8618
# Epoch 9/20
# 60000/60000 [==============================] - 3s 51us/sample - loss: 37.3079
# Epoch 10/20
# 60000/60000 [==============================] - 3s 51us/sample - loss: 36.8393
# Epoch 11/20
# 60000/60000 [==============================] - 3s 51us/sample - loss: 36.4777
# Epoch 12/20
# 60000/60000 [==============================] - 3s 52us/sample - loss: 36.2790
# Epoch 13/20
# 60000/60000 [==============================] - 3s 52us/sample - loss: 36.0128
# Epoch 14/20
# 60000/60000 [==============================] - 3s 52us/sample - loss: 35.7666
# Epoch 15/20
# 60000/60000 [==============================] - 3s 48us/sample - loss: 35.5757
# Epoch 16/20
# 60000/60000 [==============================] - 3s 49us/sample - loss: 35.4442s - l
# Epoch 17/20
# 60000/60000 [==============================] - 3s 52us/sample - loss: 35.3038
# Epoch 18/20
# 60000/60000 [==============================] - 3s 49us/sample - loss: 35.1473
# Epoch 19/20
# 60000/60000 [==============================] - 3s 52us/sample - loss: 35.0312
# Epoch 20/20
# 60000/60000 [==============================] - 3s 52us/sample - loss: 34.8953

# %%
VAE.save_weights('VAE_model_weights7.h5') #儲存模型權重

# %% [markdown]
# ### 4.視覺化呈現

# %% [markdown]
# * Encoder部分

# %%
VAE_Encoder = Model(x, z_mean)

VAE_Encoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_19 (Dense)             (None, 200)               157000
# _________________________________________________________________
# dense_20 (Dense)             (None, 50)                10050
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 167,152
# Trainable params: 167,152
# Non-trainable params: 0
# _________________________________________________________________

# %%
idx = np.random.randint(X_train.shape[0])
print(f"第 {idx} 圖的 latent 表示為 {VAE_Encoder.predict(X_train[idx: idx+1]).squeeze()}")
# Out:
# 第 45734 圖的 latent 表示為 [-1.9569583 -0.8140863]

# %%
indice = np.random.randint(X_train.shape[0],size=5000)

# %%
VAE_Encoder.predict(X_train[indice])
# Out:
# array([[ 0.5603757 , -0.13661888],
#        [ 1.7321208 ,  1.0895175 ],
#        [ 1.4141146 , -0.32583848],
#        ...,
#        [-0.6042283 , -0.54798555],
#        [ 0.457304  ,  0.40577033],
#        [ 0.39089352,  0.5725499 ]], dtype=float32)

# %%
VAE_latents = VAE_Encoder.predict(X_train[indice])

# %%
plt.figure(figsize=(10, 8))
plt.scatter(VAE_latents[:, 0], VAE_latents[:, 1], c=y_train0[indice], cmap='tab20')
plt.colorbar()
plt.show()

# %% [markdown]
# * Decoder部分

# %%
VAE_Decoder = Model(z_input, dec_1(dec_2(dec_3(z_input))))

VAE_Decoder.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 50)                150
# _________________________________________________________________
# dense_24 (Dense)             (None, 200)               10200
# _________________________________________________________________
# dense_25 (Dense)             (None, 784)               157584
# =================================================================
# Total params: 167,934
# Trainable params: 167,934
# Non-trainable params: 0
# _________________________________________________________________

# %%
def normalized(x):
    x -= x.min()
    x /= x.max()
    return x

# %%
n=16
digit_size=28
grid_x_vae = np.linspace(-4+0.05, 4-0.05, n)
grid_y_vae = np.linspace(-4+0.05, 4-0.05, n)
VAE_figure = np.zeros((digit_size * n, digit_size * n))
for i, yi in enumerate(grid_x_vae):
    for j, xi in enumerate(grid_y_vae):
        z_sample = np.array([[xi, yi]])
        x_decoded = VAE_Decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        VAE_figure[(n-i-1) * digit_size: (n - i) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = normalized(digit)

# %%
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
XXX, YYY = np.meshgrid(grid_x_vae, grid_y_vae)
plt.scatter(XXX, YYY)

plt.subplot(1, 2, 2)
plt.imshow(VAE_figure, cmap='Greys')
plt.axis('off')
plt.show()
