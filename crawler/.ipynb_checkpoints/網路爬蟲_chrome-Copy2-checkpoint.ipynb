# %%
from selenium import webdriver
import time
import urllib
import os

# %%
# 存圖位置
local_path = r"C:\Users\ena88\Desktop\mask"

# %%
driverPath = r"C:\Users\ena88\Downloads\chromedriver_win32 _1\chromedriver.exe" #填入剛剛記下的路徑
driver = webdriver.Chrome(driverPath)
driver.set_window_size(1024, 960)

# %%
driver.get("https://www.bing.com/?scope=images&nr=1&FORM=NOFORM") #前往這個網址

# %%
time.sleep(2)

# %%
search_input = driver.find_element_by_name("q")
search_input.send_keys('戴口罩')

# %%
time.sleep(2)

# %%
start_search_btn = driver.find_element_by_class_name("search icon tooltip")
start_search_btn.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-10-6e510b3643e1> in <module>
# ----> 1 start_search_btn = driver.find_element_by_class_name("search icon tooltip")
#       2 start_search_btn.click()
#
# c:\users\ena88\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\users\ena88\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
driver.maximize_window()

# %%
img_url_dic = {}

# %%
xpath = '//img[@class="mimg rms_img"]'

# %%
pos = 0  
m = 0 # 圖片編號 
for i in range(100):  
    pos += i*500 # 每次下滾500  
    js = "document.documentElement.scrollTop=%d" % pos  
    driver.execute_script(js)  
    time.sleep(1)
    
    for element in driver.find_elements_by_xpath(xpath):
        try:
            img_url = element.get_attribute('src')
            
            # 保存圖片到指定路徑
            if img_url != None and not img_url in img_url_dic:
                img_url_dic[img_url] = ''  
                m += 1
                # print(img_url)
                ext = img_url.split('/')[-1]
                # print(ext)
                filename = str(m) + 'mask' + '_' + ext +'.jpg'
                print(filename)
                
                # 保存圖片
                urllib.request.urlretrieve(img_url, os.path.join(local_path , filename))
                
        except OSError:
            print('發生OSError!')
            print(pos)
            break;
            
driver.close()
# Out:
# 1mask_images?q=tbn%3AANd9GcSfulrzit7Q8kp9moRafdk6y1yrGjnyBusc6DEz5sbWvcXyGyQz&usqp=CAU.jpg
# 發生OSError!
# 0
# 2mask_images?q=tbn%3AANd9GcRaKhrkJOattVLxDDwxYwA8yUyNFIJ8c0ZYS8dUJoPU3Zrcdw66&usqp=CAU.jpg
# 發生OSError!
# 500
# 3mask_images?q=tbn%3AANd9GcS4PF_t7yjDHzIKlGKcG3LmvkKwKrYNx8AcsQuxWd4ImBQmUllU&usqp=CAU.jpg
# 發生OSError!
# 1500
# 4mask_images?q=tbn%3AANd9GcT_nZClKZ0oCLJ4u_0yb_QSw9UtwCR3HzqCbaX7sYqdeBLx4pMf&usqp=CAU.jpg
# 發生OSError!
# 3000
# 5mask_images?q=tbn%3AANd9GcSefjd9eZx4gUdGmVHC1cDsEQmqlh8qqRPZeMp3xIkyX6BrwiDm&usqp=CAU.jpg
# 發生OSError!
# 5000
# 6mask_images?q=tbn%3AANd9GcS87d7BdhfiGn3mz1gkTkectsZSgFwRkhYRVkMcQTw33PY6JYhh&usqp=CAU.jpg
# 發生OSError!
# 7500
# 7mask_images?q=tbn%3AANd9GcSrUQX9bv0X2g6VNrSt4pc2sooEFWnOnuJ6kgRXLm_tT8Tlplq4&usqp=CAU.jpg
# 發生OSError!
# 10500
# 8mask_images?q=tbn%3AANd9GcT45Ej4aezia0SoPxUB0YhZbcnNPsTBT44v8OlXRSzKD9CPRuRG&usqp=CAU.jpg
# 發生OSError!
# 14000
# 9mask_images?q=tbn%3AANd9GcSgWtMxIL0CrrJgIHw3Zd2_nSFd-eMDGGr1qme29Xdjk3h0JBx0&usqp=CAU.jpg
# ...
