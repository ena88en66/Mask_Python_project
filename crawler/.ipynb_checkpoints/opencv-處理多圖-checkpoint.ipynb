# %%
import os
import cv2
import matplotlib.pyplot as plt # plt 用於顯示圖片
import matplotlib.image as mpimg # mpimg 用於讀取圖片
import numpy as np
from PIL import Image
# %matplotlib inline

# %%
array_of_img = []

# %%
def read_directory(directory_name):
    global array_of_img
    # this loop is for read each image in this foder,directory_name is the foder name with images.
    for filename in os.listdir(r"./"+directory_name):
        #print(filename) #just for test
        #img is used to store the image data 
        img = mpimg.imread(directory_name + "/" + filename)
        array_of_img.append(img)

# %%
read_directory("有戴口罩_B")

# %%
type(array_of_img)
# Out:
# list

# %%
len(array_of_img)
# Out:
# 567

# %%
array=np.array(array_of_img)
type(array)
# Out:
# numpy.ndarray

# %%
plt.imshow(array[0])

# %%
array[0].shape
# Out:
# (400, 400, 3)

# %%
a = cv2.resize(array[0], dsize=(256, 256), interpolation=cv2.INTER_CUBIC)

# %%
a.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(a)

# %%
b = []

# %%
image_resize = np.array(b)

# %%
type(image_resize)
# Out:
# numpy.ndarray

# %%
for i in range(0,566):
    filename = 'image_resize' + str(i)
    filename  = cv2.resize(array[i], dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
    #image_resize[i]  = cv2.resize(array[i], dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
    print (filename )
    print (filename.shape)
    #image_resize.save('B' + str(i) + '.jpg')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-0e714d80c4c5> in <module>
#       2     #filename = 'image_resize' + str(i)
#       3     #filename  = cv2.resize(array[i], dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
# ----> 4     image_resize[i]  = cv2.resize(array[i], dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
#       5     print (image_resize[i])
#       6     print (image_resize[i].shape)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
filename[0].size
# Out:
# 768

# %%
image_resize
# Out:
# array([], dtype=float64)

# %%
filename.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(image_resize)

# %%
cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_CUBIC)

# %%
os.getcwd() #當前路徑
# Out:
# 'C:\\Users\\ena88\\Desktop\\MASK'
