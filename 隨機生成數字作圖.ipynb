# %%
import numpy as np

# %%
a = list(range(1,2000,10))

# %%
b = np.array(a)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(b)

# %%
import random as ra

# %%
import pandas as pd

# %%
g = pd.Series(ra.randint(1,100) for _ in range(1000))

# %%
h = pd.DataFrame(ra.random() for _ in range(100))

# %%
plt.plot(h)

# %%
z = pd.Series(ra.randint(1,100) for _ in range(1000))

# %%
z
# Out:
# 0      98
# 1      75
# 2      66
# 3       6
# 4      34
# 5      19
# 6      48
# 7      50
# 8      37
# 9      20
# 10     21
# 11     47
# 12     88
# 13     66
# 14      8
# 15     64
# 16     32
# 17     70
# 18     37
# 19     90
# 20     58
# 21     85
# 22     56
# 23     40
# 24     38
# 25      6
# 26     33
# 27     53
# 28     62
# 29     94
#        ..
# 970    30
# 971    89
# 972    99
# 973    26
# 974    34
# 975    40
# 976    68
# 977    95
# 978    17
# 979    32
# 980    36
# 981    46
# 982    26
# 983    29
# 984    98
# 985    40
# 986    68
# 987    40
# 988    90
# 989     1
# 990    18
# 991    86
# 992    16
# 993    79
# 994    66
# 995    75
# 996    69
# 997    48
# 998     8
# 999     5
# Length: 1000, dtype: int64

# %%
y = z.value_counts()

# %%
x = pd.DataFrame(y, columns=['count'])

# %%
plt.scatter(x,y)
